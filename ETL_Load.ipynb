# %% [markdown]
# ### Connect to MySQL database

# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
connection_string = "mysql://root:{password}@localhost:3306/shot_chicago_db"
engine = create_engine(connection_string)

# %%
engine.table_names()
# Out:
# ['censusdata', 'crimedata', 'flushot']

# %% [markdown]
# ### Load cleaned dataframe and export to MySQL

# %%
#Load census dataframe
cleaned_census_df = pd.read_csv("cleaned_census_df.csv")

# %%
#Load dataframe into SQL
cleaned_census_df.to_sql(name='censusdata', con=engine, if_exists='append', index=False)

# %%
#Confirm data has been added
pd.read_sql_query('select * from censusdata', con=engine).head()
# Out:
#    Unnamed: 0  community_area_number            Area   <19y  20-34y  35-59y  \
# 0         0.0                    1.0     Rogers Park  12092   16967   12526
# 1         1.0                    2.0      West Ridge  19951   16264   14581
# 2         2.0                    3.0          Uptown   7030   18725   13253
# 3         3.0                    4.0  Lincoln Square   7306   13696   10180
# 4         4.0                    5.0    North Center   8266   10302    9454
#
#    50-64y  65-74y  75-84y  85y<      ...        ASSOC   BACH  GRAD_PROF  \
# 0    9130    2718    1268   799      ...         1825   9693       6627
# 1   13704    5138    2765  1320      ...         2830  12247       7161
# 2   10706    3333    1977  1272      ...         2329  15315       9176
# 3    6588    2228     976   509      ...         1527  11589       7831
# 4    4024    1602     808   486      ...          925  10509       7017
#
#    INC_LT_25K  INC_25_50K  INC_50_75K  INC_75_100K  INC_100_150K  INC_GT_150  \
# 0        8558        6268        4048         2167          1944        1273
# 1        6180        6501        3965         2652          3302        2182
# 2        9629        5794        4321         3120          3293        3079
# 3        3263        3987        3043         2512          2745        2882
# 4        1416        1870        2185         1986          2677        4415
#
#    median_income
# 0          37549
# 1          48701
# 2          45644
# 3          66393
# 4          97703
#
# [5 rows x 33 columns]

# %%
#Load flushot dataframe
cleaned_flu_df = pd.read_csv("cleaned_flu_df.csv")

# %%
#Load dataframe into SQL
cleaned_flu_df.to_sql(name='flushot', con=engine, if_exists='append', index=False)

# %%
#Confirm data has been added
pd.read_sql_query('select * from flushot', con=engine).head()
# Out:
#    Unnamed: 0     Season   Latitude  Longitude  Postal Code  \
# 0         0.0  2017-2018  41.968500 -87.728760        60630
# 1         1.0  2015-2016  41.981429 -87.668555        60640
# 2         2.0  2015-2016  41.884543 -87.627803        60601
# 3         3.0  2015-2016  41.844305 -87.707719        60623
# 4         4.0  2016-2017  41.968300 -87.738086        60630
#
#    community_area_number
# 0                   14.0
# 1                   76.0
# 2                   38.0
# 3                   32.0
# 4                   14.0

# %%
#Load crimedata dataframe
crimedata_df = pd.read_csv("crime2013_2019.csv")
crimedata_df = crimedata_df.rename(columns={"Community Area":"community_area_number"})

# %%
#Load CSV into SQL
crimedata_df.to_sql(name='crimedata', con=engine, if_exists='append', index=False)

# %%
#Confirm data has been added
pd.read_sql_query('select * from crimedata', con=engine).head()
# Out:
#    Unnamed: 0        ID        Date        Primary Type Location Description  \
# 0           0  11668131  04/26/2019  DECEPTIVE PRACTICE          GAS STATION
# 1           1  11668274  04/26/2019            BURGLARY            APARTMENT
# 2           2  11668155  04/26/2019           NARCOTICS        PARK PROPERTY
# 3           3  11668197  04/26/2019   WEAPONS VIOLATION               STREET
# 4           4  11668158  04/26/2019             BATTERY            APARTMENT
#
#    Arrest  community_area_number  Year   Latitude  Longitude      Time AmPm
# 0       0                   25.0  2019  41.912867 -87.765636  11:58:00   PM
# 1       0                   24.0  2019  41.896700 -87.655246  11:58:00   PM
# 2       1                   15.0  2019  41.965938 -87.781969  11:56:00   PM
# 3       1                   71.0  2019  41.743674 -87.634697  11:51:00   PM
# 4       0                   25.0  2019  41.876749 -87.747879  11:49:00   PM

# %% [markdown]
# ### Combine tables in SQL

# %%
#Combine flushot data and census data

query = """
SELECT
*
FROM censusdata A
INNER JOIN flushot B on A.community_area_number = B.community_area_number
"""

pd.read_sql_query(query, con=engine).head()
# Out:
#    Unnamed: 0  community_area_number         Area   <19y  20-34y  35-59y  \
# 0        13.0                   14.0  Albany Park  13354   13738   11975
# 1        13.0                   14.0  Albany Park  13354   13738   11975
# 2         NaN                   14.0  Albany Park  13354   13738   11975
# 3        13.0                   14.0  Albany Park  13354   13738   11975
# 4         NaN                   14.0  Albany Park  13354   13738   11975
#
#    50-64y  65-74y  75-84y  85y<          ...            INC_75_100K  \
# 0    8232    2329    1343   604          ...                   2091
# 1    8232    2329    1343   604          ...                   2091
# 2    8232    2329    1343   604          ...                   2091
# 3    8232    2329    1343   604          ...                   2091
# 4    8232    2329    1343   604          ...                   2091
#
#    INC_100_150K  INC_GT_150  median_income  Unnamed: 0     Season  Latitude  \
# 0          2259        1632          55561         0.0  2017-2018   41.9685
# 1          2259        1632          55561         0.0  2017-2018   41.9685
# 2          2259        1632          55561         0.0  2017-2018   41.9685
# 3          2259        1632          55561         0.0  2017-2018   41.9685
# 4          2259        1632          55561         0.0  2017-2018   41.9685
#
#    Longitude  Postal Code  community_area_number
# 0  -87.72876        60630                   14.0
# 1  -87.72876        60630                   14.0
# 2  -87.72876        60630                   14.0
# 3  -87.72876        60630                   14.0
# 4  -87.72876        60630                   14.0
#
# [5 rows x 39 columns]
